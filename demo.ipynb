# %%
import pandas as pd

# %%
pd.read_csv(r"G:\000 - Python Projects\006 - XAI project visual analytics\va_explainable_ai\numerical datasets\Data on the weekly subnational 14-day notification rate of new COVID-19 cases.csv")
# Out:
#        country      region_name nuts_code year_week  rate_14_day_per_100k  \
# 0      Austria       Burgenland      AT11   2020-13                   NaN
# 1      Austria       Burgenland      AT11   2020-14             38.378459
# 2      Austria       Burgenland      AT11   2020-15             37.019930
# 3      Austria       Burgenland      AT11   2020-16             27.849855
# 4      Austria       Burgenland      AT11   2020-17             13.924928
# ...        ...              ...       ...       ...                   ...
# 22581   Sweden  Norrbottens Lan     SE332   2021-18            778.510394
# 22582   Sweden  Norrbottens Lan     SE332   2021-19            786.907270
# 22583   Sweden  Norrbottens Lan     SE332   2021-20            811.298197
# 22584   Sweden  Norrbottens Lan     SE332   2021-21            514.208714
# 22585   Sweden  Norrbottens Lan     SE332   2021-22            470.624928
#
#                                                source
# ...
